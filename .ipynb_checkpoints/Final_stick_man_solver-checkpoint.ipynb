# %%
import subprocess
import matplotlib.image as img
import urllib
import time

subprocess.call(['adb','devices']);

while True:
    subprocess.call(['adb','shell','screencap','/sdcard/trial.png']);
    subprocess.call(['adb','pull','/sdcard/trial.png']);
    
    jpgdata=img.imread('trial.png');
# 0.5529412
# 0.7647059
# 0.38039216
    if (jpgdata[1650,510,0]>0.55 and jpgdata[1650,510,1]>0.76 and jpgdata[1650,510,2]>0.38):
        subprocess.call(['adb','shell','input','swipe','1650','520','1650','520','300']);
        print("game over page");
        time.sleep(2);
        continue;
    elif (jpgdata[1712,150,0]+jpgdata[1712,150,1]+jpgdata[1712,150,2])>0:
        subprocess.call(['adb','shell','input','keyevent','4']);
        print("add       page");
        print(jpgdata[1650,510,0]);print(jpgdata[1650,510,1]);print(jpgdata[1650,510,2]);
        time.sleep(2);
        continue;
    print("game      page");
    x=1712;y=200;start=0;mid=0;
    while True:
        p1=jpgdata[x,y,0];
        p2=jpgdata[x,y,1];
        p3=jpgdata[x,y,2];
        if (p1==0 and p2==0 and p3==0):
            if start==0:
                start=y;
            y+=2;
        elif start>0:
            mid=y;
            break;
        else:
            y+=2;
        if y>1000:
            mid=1000;
            break;

    tt=(mid-152)*1.8;
    t=int(tt);
    xyz=['adb','shell','input','swipe','500','500','500','500',str(t)];
    subprocess.call(xyz);

    time.sleep(3);
# Out:
# add       page
# 0.5529412
# 0.7647059
# 0.38039216
# add       page
# 0.5529412
# 0.7647059
# 0.38039216
# add       page
# 0.5529412
# 0.7647059
# 0.38039216
# add       page
# 0.5529412
# 0.7647059
# 0.38039216
# add       page
# 0.5529412
# 0.7647059
# 0.38039216
# add       page
# 0.5529412
# 0.7647059
# 0.38039216
# add       page
# 0.5529412
# 0.7647059
# 0.38039216
# game      page
# game      page
# game      page
# game      page
# game      page
# game      page
# game      page
# game      page
# game      page
# game      page
# game over page
# game over page
# game over page
# game over page
# game over page
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-7ee09495e1a1> in <module>()
#      15         subprocess.call(['adb','shell','input','swipe','1650','520','1650','520','300']);
#      16         print("game over page");
# ---> 17         time.sleep(2);
#      18         continue;
#      19     elif (jpgdata[1712,150,0]+jpgdata[1712,150,1]+jpgdata[1712,150,2])>0:
#
# KeyboardInterrupt:
